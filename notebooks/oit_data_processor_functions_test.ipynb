# %%
import sys
from pathlib import Path

# Añade el directorio raíz del proyecto al sys.path
project_root = Path('../src').resolve()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
from processing_data.oit_data_processor import *

# %%
filename = 'youth_working-age_population_by_sex,_age_and_education_(thousands).csv'
filepath = f'../data/raw/{filename}'
rename_map = {
                'sex.label': 'sex',
                'classif1.label': 'classif1',
                'classif2.label': 'classif2'
            }
column_to_keep = ['time', 'sex', 'classif1', 'classif2', 'obs_value']

df1 = load_data(filepath, rename_map, column_to_keep)
export_dataframe(df1, filename=f'cleanned_{filename}')

# %%
df1
# Out:
#      time          sex                  classif1  \
# 0    2017   Sex: Total  Age (Youth bands): 15-29
# 1    2017   Sex: Total  Age (Youth bands): 15-29
# 2    2017   Sex: Total  Age (Youth bands): 15-29
# 3    2017   Sex: Total  Age (Youth bands): 15-29
# 4    2017   Sex: Total  Age (Youth bands): 15-29
# ..    ...          ...                       ...
# 646  2005  Sex: Female  Age (Youth bands): 25-29
# 647  2005  Sex: Female  Age (Youth bands): 25-29
# 648  2005  Sex: Female  Age (Youth bands): 25-29
# 649  2005  Sex: Female  Age (Youth bands): 25-29
# 650  2005  Sex: Female  Age (Youth bands): 25-29
#
#                                            classif2  obs_value
# 0               Education (Aggregate levels): Total   7988.515
# 1     Education (Aggregate levels): Less than basic    101.121
# 2               Education (Aggregate levels): Basic   2148.420
# 3        Education (Aggregate levels): Intermediate   3169.844
# ...

# %%
df1_no_total = remove_totals(df1, ['sex', 'classif1', 'classif2'])
df1_no_total
# Out:
#      time          sex                  classif1  \
# 0    2017    Sex: Male  Age (Youth bands): 15-29
# 1    2017    Sex: Male  Age (Youth bands): 15-29
# 2    2017    Sex: Male  Age (Youth bands): 15-29
# 3    2017    Sex: Male  Age (Youth bands): 15-29
# 4    2017    Sex: Male  Age (Youth bands): 15-29
# ..    ...          ...                       ...
# 349  2005  Sex: Female  Age (Youth bands): 25-29
# 350  2005  Sex: Female  Age (Youth bands): 25-29
# 351  2005  Sex: Female  Age (Youth bands): 25-29
# 352  2005  Sex: Female  Age (Youth bands): 25-29
# 353  2005  Sex: Female  Age (Youth bands): 25-29
#
#                                            classif2  obs_value
# 0     Education (Aggregate levels): Less than basic     64.063
# 1               Education (Aggregate levels): Basic   1248.967
# 2        Education (Aggregate levels): Intermediate   1679.162
# 3            Education (Aggregate levels): Advanced   1077.501
# ...

# %%
df1_filled_no_total = fill_missing_values(df1_no_total, group_cols=['sex', 'classif1', 'classif2'])
df1_filled_no_total
# Out:
#      time          sex                  classif1  \
# 0    2017    Sex: Male  Age (Youth bands): 15-29
# 1    2017    Sex: Male  Age (Youth bands): 15-29
# 2    2017    Sex: Male  Age (Youth bands): 15-29
# 3    2017    Sex: Male  Age (Youth bands): 15-29
# 4    2017    Sex: Male  Age (Youth bands): 15-29
# ..    ...          ...                       ...
# 349  2005  Sex: Female  Age (Youth bands): 25-29
# 350  2005  Sex: Female  Age (Youth bands): 25-29
# 351  2005  Sex: Female  Age (Youth bands): 25-29
# 352  2005  Sex: Female  Age (Youth bands): 25-29
# 353  2005  Sex: Female  Age (Youth bands): 25-29
#
#                                            classif2    obs_value
# 0     Education (Aggregate levels): Less than basic    64.063000
# 1               Education (Aggregate levels): Basic  1248.967000
# 2        Education (Aggregate levels): Intermediate  1679.162000
# 3            Education (Aggregate levels): Advanced  1077.501000
# ...

# %%
df1_filled  = fill_missing_values(df1, group_cols=['sex', 'classif1', 'classif2'])
df1_filled
# Out:
#      time          sex                  classif1  \
# 0    2017   Sex: Total  Age (Youth bands): 15-29
# 1    2017   Sex: Total  Age (Youth bands): 15-29
# 2    2017   Sex: Total  Age (Youth bands): 15-29
# 3    2017   Sex: Total  Age (Youth bands): 15-29
# 4    2017   Sex: Total  Age (Youth bands): 15-29
# ..    ...          ...                       ...
# 646  2005  Sex: Female  Age (Youth bands): 25-29
# 647  2005  Sex: Female  Age (Youth bands): 25-29
# 648  2005  Sex: Female  Age (Youth bands): 25-29
# 649  2005  Sex: Female  Age (Youth bands): 25-29
# 650  2005  Sex: Female  Age (Youth bands): 25-29
#
#                                            classif2    obs_value
# 0               Education (Aggregate levels): Total  7988.515000
# 1     Education (Aggregate levels): Less than basic   101.121000
# 2               Education (Aggregate levels): Basic  2148.420000
# 3        Education (Aggregate levels): Intermediate  3169.844000
# ...

# %%
df1
# Out:
#      time          sex                  classif1  \
# 0    2017   Sex: Total  Age (Youth bands): 15-29
# 1    2017   Sex: Total  Age (Youth bands): 15-29
# 2    2017   Sex: Total  Age (Youth bands): 15-29
# 3    2017   Sex: Total  Age (Youth bands): 15-29
# 4    2017   Sex: Total  Age (Youth bands): 15-29
# ..    ...          ...                       ...
# 646  2005  Sex: Female  Age (Youth bands): 25-29
# 647  2005  Sex: Female  Age (Youth bands): 25-29
# 648  2005  Sex: Female  Age (Youth bands): 25-29
# 649  2005  Sex: Female  Age (Youth bands): 25-29
# 650  2005  Sex: Female  Age (Youth bands): 25-29
#
#                                            classif2    obs_value
# 0               Education (Aggregate levels): Total  7988.515000
# 1     Education (Aggregate levels): Less than basic   101.121000
# 2               Education (Aggregate levels): Basic  2148.420000
# 3        Education (Aggregate levels): Intermediate  3169.844000
# ...

# %%
pivot1 = create_pivot_table(df1, 'time', 'classif2')
pivot1

# %%
pivot2 = create_pivot_table(df1, 'time','classif1')
pivot2

# %%
pivot3 = create_pivot_table(df1, 'classif1', 'classif2')
pivot3

# %%
pivot4 = create_pivot_table(df1, 'classif2','classif1')
pivot4

# %%
pivot5 = create_pivot_table(df1, 'time', 'sex')
pivot5

# %%
filename2 = 'labour_force_by_sex,_age_and_education_(thousands).csv'
filepath2 = f'../data/raw/{filename2}'

df2 = load_data(filepath2, rename_columns=rename_map)
export_dataframe(df2, filename=f'cleanned_{filename2}')

# %%
df2
# Out:
#                           ref_area.label                   source.label  \
# 0     Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
# 1     Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
# 2     Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
# 3     Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
# 4     Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
# ...                                  ...                            ...
# 6739  Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
# 6740  Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
# 6741  Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
# 6742  Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
# 6743  Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
#
#                                         indicator.label          sex  \
# ...

# %%
filename3 = 'public_sector_employment_by_sex_and_age_(thousands).csv'
filepath3 = f'../data/raw/{filename3}'
rename_map = {
                'sex.label': 'sex',
                'classif1.label': 'classif1',
                'classif2.label': 'classif2'
            }


df3 = load_data(filepath, rename_columns=rename_map)
export_dataframe(df3, filename=f'cleanned_{filename3}')

# %%
df3
# Out:
#                          ref_area.label                   source.label  \
# 0    Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
# 1    Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
# 2    Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
# 3    Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
# 4    Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
# ..                                  ...                            ...
# 646  Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
# 647  Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
# 648  Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
# 649  Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
# 650  Venezuela (Bolivarian Republic of)  LFS - Household Sample Survey
#
#                                        indicator.label          sex  \
# ...
