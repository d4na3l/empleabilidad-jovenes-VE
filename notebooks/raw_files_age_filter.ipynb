# %%
import os
import shutil

# %%
def move_files_with_age(source_folder, destination_folder):
  """
  Mueve todos los archivos que contengan la palabra 'age' en su nombre
  desde la carpeta source_folder a la carpeta destination_folder.

  Args:
    source_folder: La ruta de la carpeta de origen.
    destination_folder: La ruta de la carpeta de destino.
  """

  for filename in os.listdir(source_folder):
    if 'age' in filename:
      source_file = os.path.join(source_folder, filename)
      destination = os.path.join(destination_folder, filename)
      shutil.move(source_file, destination)
      print(f"Movido: {source_file} a {destination}")

# %%
# Ejemplo de uso:
source_dir = "../data/raw/"
destination_dir = "../data/raw/filtering"

move_files_with_age(source_dir, destination_dir)
# Out:
# Movido: ../data/raw/mean_weekly_hours_actually_worked_per_employed_person_by_age_and_economic_activity_-_isic_level_2.csv a ../data/raw/filtering/mean_weekly_hours_actually_worked_per_employed_person_by_age_and_economic_activity_-_isic_level_2.csv
# Movido: ../data/raw/composite_rate_of_labour_underutilization_(lu4)_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2020_(%).csv a ../data/raw/filtering/composite_rate_of_labour_underutilization_(lu4)_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2020_(%).csv
# Movido: ../data/raw/average_hourly_earnings_of_employees_by_sex_and_occupation.csv a ../data/raw/filtering/average_hourly_earnings_of_employees_by_sex_and_occupation.csv
# Movido: ../data/raw/labour_force_by_sex_and_age_--_ilo_modelled_estimates,_nov._2023_(thousands).csv a ../data/raw/filtering/labour_force_by_sex_and_age_--_ilo_modelled_estimates,_nov._2023_(thousands).csv
# Movido: ../data/raw/youth_unemployment_rate_by_sex,_age_and_education_(%).csv a ../data/raw/filtering/youth_unemployment_rate_by_sex,_age_and_education_(%).csv
# Movido: ../data/raw/youth_working-age_population_by_sex,_age_and_school_attendance_status_(thousands).csv a ../data/raw/filtering/youth_working-age_population_by_sex,_age_and_school_attendance_status_(thousands).csv
# Movido: ../data/raw/working-age_population_by_sex_and_age_(thousands).csv a ../data/raw/filtering/working-age_population_by_sex_and_age_(thousands).csv
# Movido: ../data/raw/prime-age_unemployment_rate_by_sex,_household_type_and_presence_of_children_(%).csv a ../data/raw/filtering/prime-age_unemployment_rate_by_sex,_household_type_and_presence_of_children_(%).csv
# Movido: ../data/raw/prime-age_labour_force_participation_rate_by_sex,_household_type_and_presence_of_children_(%).csv a ../data/raw/filtering/prime-age_labour_force_participation_rate_by_sex,_household_type_and_presence_of_children_(%).csv
# Movido: ../data/raw/employment_by_age_and_status_in_employment_--_ilo_modelled_estimates,_nov._2023_(thousands).csv a ../data/raw/filtering/employment_by_age_and_status_in_employment_--_ilo_modelled_estimates,_nov._2023_(thousands).csv
# Movido: ../data/raw/mean_weekly_hours_actually_worked_per_employee_by_sex,_age_and_occupation.csv a ../data/raw/filtering/mean_weekly_hours_actually_worked_per_employee_by_sex,_age_and_occupation.csv
# Movido: ../data/raw/mean_weekly_hours_actually_worked_per_employee_by_sex,_age_and_economic_activity.csv a ../data/raw/filtering/mean_weekly_hours_actually_worked_per_employee_by_sex,_age_and_economic_activity.csv
# Movido: ../data/raw/unemployment_rate_by_sex,_age_and_education_(%).csv a ../data/raw/filtering/unemployment_rate_by_sex,_age_and_education_(%).csv
# Movido: ../data/raw/working-age_population_by_sex,_age_and_education_(thousands).csv a ../data/raw/filtering/working-age_population_by_sex,_age_and_education_(thousands).csv
# Movido: ../data/raw/employment_outside_the_formal_sector_by_sex,_age_and_occupation_(thousands).csv a ../data/raw/filtering/employment_outside_the_formal_sector_by_sex,_age_and_occupation_(thousands).csv
# Movido: ../data/raw/labour_force_by_sex,_age_and_marital_status_(thousands).csv a ../data/raw/filtering/labour_force_by_sex,_age_and_marital_status_(thousands).csv
# Movido: ../data/raw/employment-to-population_ratio_by_sex,_age_and_marital_status_(%).csv a ../data/raw/filtering/employment-to-population_ratio_by_sex,_age_and_marital_status_(%).csv
# Movido: ../data/raw/share_of_employment_outside_the_formal_sector_by_sex,_age_and_education_(%).csv a ../data/raw/filtering/share_of_employment_outside_the_formal_sector_by_sex,_age_and_education_(%).csv
# Movido: ../data/raw/youth_inactivity_rate_by_sex,_age_and_school_attendance_status_(%).csv a ../data/raw/filtering/youth_inactivity_rate_by_sex,_age_and_school_attendance_status_(%).csv
# Movido: ../data/raw/youth_labour_force_by_sex,_age_and_school_attendance_status_(thousands).csv a ../data/raw/filtering/youth_labour_force_by_sex,_age_and_school_attendance_status_(thousands).csv
# Movido: ../data/raw/unemployment_by_sex_and_age_(thousands).csv a ../data/raw/filtering/unemployment_by_sex_and_age_(thousands).csv
# Movido: ../data/raw/youth_unemployment_by_sex,_age_and_duration_(thousands).csv a ../data/raw/filtering/youth_unemployment_by_sex,_age_and_duration_(thousands).csv
# Movido: ../data/raw/mean_weekly_hours_actually_worked_per_employee_by_sex,_age_and_public-private_sector.csv a ../data/raw/filtering/mean_weekly_hours_actually_worked_per_employee_by_sex,_age_and_public-private_sector.csv
# Movido: ../data/raw/youth_employment_by_sex,_age_and_school_attendance_status_(thousands).csv a ../data/raw/filtering/youth_employment_by_sex,_age_and_school_attendance_status_(thousands).csv
# Movido: ../data/raw/labour_force_participation_rate_by_sex,_age_and_education_(%).csv a ../data/raw/filtering/labour_force_participation_rate_by_sex,_age_and_education_(%).csv
# Movido: ../data/raw/youth_outside_the_labour_force_by_sex,_age_and_school_attendance_status_(thousands).csv a ../data/raw/filtering/youth_outside_the_labour_force_by_sex,_age_and_school_attendance_status_(thousands).csv
# Movido: ../data/raw/youth_unemployment_by_sex,_age_and_education_(thousands).csv a ../data/raw/filtering/youth_unemployment_by_sex,_age_and_education_(thousands).csv
# Movido: ../data/raw/youth_unemployment-to-population_ratio_by_sex,_age_and_education_(%).csv a ../data/raw/filtering/youth_unemployment-to-population_ratio_by_sex,_age_and_education_(%).csv
# Movido: ../data/raw/population_by_sex,_age_and_rural_-_urban_areas_--_un_estimates,_july_2022_(thousands).csv a ../data/raw/filtering/population_by_sex,_age_and_rural_-_urban_areas_--_un_estimates,_july_2022_(thousands).csv
# Movido: ../data/raw/employment_by_sex,_age_and_status_in_employment_(thousands).csv a ../data/raw/filtering/employment_by_sex,_age_and_status_in_employment_(thousands).csv
# Movido: ../data/raw/youth_labour_force_by_sex,_age_and_education_(thousands).csv a ../data/raw/filtering/youth_labour_force_by_sex,_age_and_education_(thousands).csv
# Movido: ../data/raw/employees_by_sex,_age_and_education_(thousands).csv a ../data/raw/filtering/employees_by_sex,_age_and_education_(thousands).csv
# Movido: ../data/raw/labour_force_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2021_(thousands).csv a ../data/raw/filtering/labour_force_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2021_(thousands).csv
# Movido: ../data/raw/mean_weekly_hours_actually_worked_per_employed_person_by_sex,_age_and_working_time_arrangement.csv a ../data/raw/filtering/mean_weekly_hours_actually_worked_per_employed_person_by_sex,_age_and_working_time_arrangement.csv
# Movido: ../data/raw/employment_by_sex,_age_and_public-private_sector_(thousands).csv a ../data/raw/filtering/employment_by_sex,_age_and_public-private_sector_(thousands).csv
# Movido: ../data/raw/average_hourly_earnings_of_employees_by_sex_and_economic_activity.csv a ../data/raw/filtering/average_hourly_earnings_of_employees_by_sex_and_economic_activity.csv
# Movido: ../data/raw/labour_force_participation_rate_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2021_(%).csv a ../data/raw/filtering/labour_force_participation_rate_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2021_(%).csv
# Movido: ../data/raw/youth_employment_by_sex,_age_and_status_in_employment_(thousands).csv a ../data/raw/filtering/youth_employment_by_sex,_age_and_status_in_employment_(thousands).csv
# Movido: ../data/raw/informal_employment_rate_by_sex,_age_and_occupation_(%).csv a ../data/raw/filtering/informal_employment_rate_by_sex,_age_and_occupation_(%).csv
# Movido: ../data/raw/youth_employment_by_sex,_age_and_economic_activity_(thousands).csv a ../data/raw/filtering/youth_employment_by_sex,_age_and_economic_activity_(thousands).csv
# Movido: ../data/raw/informal_employment_by_sex,_age_and_economic_activity_(thousands).csv a ../data/raw/filtering/informal_employment_by_sex,_age_and_economic_activity_(thousands).csv
# Movido: ../data/raw/working-age_population_by_sex,_marital_status_and_labour_market_status_(thousands).csv a ../data/raw/filtering/working-age_population_by_sex,_marital_status_and_labour_market_status_(thousands).csv
# Movido: ../data/raw/employment_by_sex,_age_and_marital_status_(thousands).csv a ../data/raw/filtering/employment_by_sex,_age_and_marital_status_(thousands).csv
# Movido: ../data/raw/mean_nominal_monthly_earnings_of_prime-age_employees_by_sex,_household_type_and_presence_of_children_(local_currency).csv a ../data/raw/filtering/mean_nominal_monthly_earnings_of_prime-age_employees_by_sex,_household_type_and_presence_of_children_(local_currency).csv
# Movido: ../data/raw/mean_weekly_hours_actually_worked_per_employed_person_by_sex,_age_and_economic_activity.csv a ../data/raw/filtering/mean_weekly_hours_actually_worked_per_employed_person_by_sex,_age_and_economic_activity.csv
# Movido: ../data/raw/inactivity_rate_by_sex,_age_and_marital_status_(%).csv a ../data/raw/filtering/inactivity_rate_by_sex,_age_and_marital_status_(%).csv
# Movido: ../data/raw/employment_by_sex_and_age_(thousands).csv a ../data/raw/filtering/employment_by_sex_and_age_(thousands).csv
# Movido: ../data/raw/informal_employment_by_sex,_age_and_education_(thousands).csv a ../data/raw/filtering/informal_employment_by_sex,_age_and_education_(thousands).csv
# Movido: ../data/raw/youth_unemployment-to-population_ratio_by_sex,_age_and_school_attendance_status_(%).csv a ../data/raw/filtering/youth_unemployment-to-population_ratio_by_sex,_age_and_school_attendance_status_(%).csv
# Movido: ../data/raw/public_sector_employment_by_sex_and_age_(thousands).csv a ../data/raw/filtering/public_sector_employment_by_sex_and_age_(thousands).csv
# Movido: ../data/raw/share_of_employment_outside_the_formal_sector_by_sex,_age_and_marital_status_(%).csv a ../data/raw/filtering/share_of_employment_outside_the_formal_sector_by_sex,_age_and_marital_status_(%).csv
# Movido: ../data/raw/unemployment_rate_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2021_(%).csv a ../data/raw/filtering/unemployment_rate_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2021_(%).csv
# Movido: ../data/raw/youth_labour_force_participation_rate_by_sex,_age_and_school_attendance_status_(%).csv a ../data/raw/filtering/youth_labour_force_participation_rate_by_sex,_age_and_school_attendance_status_(%).csv
# Movido: ../data/raw/youth_employment-to-population_ratio_by_sex,_age_and_school_attendance_status_(%).csv a ../data/raw/filtering/youth_employment-to-population_ratio_by_sex,_age_and_school_attendance_status_(%).csv
# Movido: ../data/raw/labour_force_participation_rate_by_sex_and_age_(%).csv a ../data/raw/filtering/labour_force_participation_rate_by_sex_and_age_(%).csv
# Movido: ../data/raw/employment-to-population_ratio_by_sex_and_age_(%).csv a ../data/raw/filtering/employment-to-population_ratio_by_sex_and_age_(%).csv
# Movido: ../data/raw/youth_unemployment_by_sex,_age_and_categories_of_unemployed_persons_(thousands).csv a ../data/raw/filtering/youth_unemployment_by_sex,_age_and_categories_of_unemployed_persons_(thousands).csv
# Movido: ../data/raw/inactivity_rate_by_sex_and_age_--_ilo_modelled_estimates,_nov._2023_(%).csv a ../data/raw/filtering/inactivity_rate_by_sex_and_age_--_ilo_modelled_estimates,_nov._2023_(%).csv
# Movido: ../data/raw/youth_labour_force_participation_rate_by_sex,_age_and_education_(%).csv a ../data/raw/filtering/youth_labour_force_participation_rate_by_sex,_age_and_education_(%).csv
# Movido: ../data/raw/youth_employment_by_sex,_age_and_working_time_arrangement_(thousands).csv a ../data/raw/filtering/youth_employment_by_sex,_age_and_working_time_arrangement_(thousands).csv
# Movido: ../data/raw/labour_force_participation_rate_by_sex,_age_and_marital_status_(%).csv a ../data/raw/filtering/labour_force_participation_rate_by_sex,_age_and_marital_status_(%).csv
# Movido: ../data/raw/youth_working-age_population_by_sex,_age_and_education_(thousands).csv a ../data/raw/filtering/youth_working-age_population_by_sex,_age_and_education_(thousands).csv
# Movido: ../data/raw/employment_by_sex,_age_and_economic_activity_(thousands).csv a ../data/raw/filtering/employment_by_sex,_age_and_economic_activity_(thousands).csv
# Movido: ../data/raw/youth_employment_by_sex,_age_and_weekly_hours_actually_worked_(thousands).csv a ../data/raw/filtering/youth_employment_by_sex,_age_and_weekly_hours_actually_worked_(thousands).csv
# Movido: ../data/raw/labour_force_by_sex,_age_and_education_(thousands).csv a ../data/raw/filtering/labour_force_by_sex,_age_and_education_(thousands).csv
# Movido: ../data/raw/employment_by_sex_and_age_--_ilo_modelled_estimates,_nov._2023_(thousands).csv a ../data/raw/filtering/employment_by_sex_and_age_--_ilo_modelled_estimates,_nov._2023_(thousands).csv
# Movido: ../data/raw/employment_outside_the_formal_sector_by_sex,_age_and_education_(thousands).csv a ../data/raw/filtering/employment_outside_the_formal_sector_by_sex,_age_and_education_(thousands).csv
# Movido: ../data/raw/employment_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2021_(thousands).csv a ../data/raw/filtering/employment_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2021_(thousands).csv
# Movido: ../data/raw/informal_employment_rate_by_sex,_age_and_economic_activity_(%).csv a ../data/raw/filtering/informal_employment_rate_by_sex,_age_and_economic_activity_(%).csv
# Movido: ../data/raw/informal_employment_by_sex,_age_and_occupation_(thousands).csv a ../data/raw/filtering/informal_employment_by_sex,_age_and_occupation_(thousands).csv
# Movido: ../data/raw/employment_outside_the_formal_sector_by_sex,_age_and_marital_status_(thousands).csv a ../data/raw/filtering/employment_outside_the_formal_sector_by_sex,_age_and_marital_status_(thousands).csv
# Movido: ../data/raw/unemployment_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2021_(thousands).csv a ../data/raw/filtering/unemployment_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2021_(thousands).csv
# Movido: ../data/raw/employment-to-population_ratio_by_sex_and_age_--_ilo_modelled_estimates,_nov._2023_(%).csv a ../data/raw/filtering/employment-to-population_ratio_by_sex_and_age_--_ilo_modelled_estimates,_nov._2023_(%).csv
# Movido: ../data/raw/youth_unemployment_by_sex,_age_and_school_attendance_status_(thousands).csv a ../data/raw/filtering/youth_unemployment_by_sex,_age_and_school_attendance_status_(thousands).csv
# Movido: ../data/raw/youth_employment_by_sex,_age_and_education_(thousands).csv a ../data/raw/filtering/youth_employment_by_sex,_age_and_education_(thousands).csv
# Movido: ../data/raw/employees_by_sex,_age_and_marital_status_(thousands).csv a ../data/raw/filtering/employees_by_sex,_age_and_marital_status_(thousands).csv
# Movido: ../data/raw/working-age_population_by_sex,_age_and_labour_market_status_(thousands).csv a ../data/raw/filtering/working-age_population_by_sex,_age_and_labour_market_status_(thousands).csv
# Movido: ../data/raw/unemployment_rate_by_sex,_age_and_marital_status_(%).csv a ../data/raw/filtering/unemployment_rate_by_sex,_age_and_marital_status_(%).csv
# Movido: ../data/raw/inactivity_rate_by_sex_and_age_(%).csv a ../data/raw/filtering/inactivity_rate_by_sex_and_age_(%).csv
# Movido: ../data/raw/time-related_underemployment_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2020_(thousands).csv a ../data/raw/filtering/time-related_underemployment_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2020_(thousands).csv
# Movido: ../data/raw/informal_employment_rate_by_sex,_age_and_education_(%).csv a ../data/raw/filtering/informal_employment_rate_by_sex,_age_and_education_(%).csv
# Movido: ../data/raw/average_monthly_earnings_of_employees_by_sex_and_education.csv a ../data/raw/filtering/average_monthly_earnings_of_employees_by_sex_and_education.csv
# Movido: ../data/raw/youth_employment_by_sex,_age_and_occupation_(thousands).csv a ../data/raw/filtering/youth_employment_by_sex,_age_and_occupation_(thousands).csv
# Movido: ../data/raw/share_of_employment_outside_the_formal_sector_by_sex,_age_and_economic_activity_(%).csv a ../data/raw/filtering/share_of_employment_outside_the_formal_sector_by_sex,_age_and_economic_activity_(%).csv
# Movido: ../data/raw/youth_employment-to-population_ratio_by_sex,_age_and_education_(%).csv a ../data/raw/filtering/youth_employment-to-population_ratio_by_sex,_age_and_education_(%).csv
# Movido: ../data/raw/mean_weekly_hours_actually_worked_per_employed_person_by_sex,_age_and_occupation.csv a ../data/raw/filtering/mean_weekly_hours_actually_worked_per_employed_person_by_sex,_age_and_occupation.csv
# Movido: ../data/raw/mean_weekly_hours_actually_worked_per_employee_by_sex,_age_and_type_of_job_contract.csv a ../data/raw/filtering/mean_weekly_hours_actually_worked_per_employee_by_sex,_age_and_type_of_job_contract.csv
# Movido: ../data/raw/average_monthly_earnings_of_employees_by_sex_and_occupation.csv a ../data/raw/filtering/average_monthly_earnings_of_employees_by_sex_and_occupation.csv
# Movido: ../data/raw/employment_by_sex,_age_and_education_(thousands).csv a ../data/raw/filtering/employment_by_sex,_age_and_education_(thousands).csv
# Movido: ../data/raw/mean_weekly_hours_actually_worked_per_employee_by_age_and_economic_activity_-_isic_level_2.csv a ../data/raw/filtering/mean_weekly_hours_actually_worked_per_employee_by_age_and_economic_activity_-_isic_level_2.csv
# Movido: ../data/raw/employees_by_age_and_economic_activity_-_isic_level_2_(thousands).csv a ../data/raw/filtering/employees_by_age_and_economic_activity_-_isic_level_2_(thousands).csv
# Movido: ../data/raw/inactivity_rate_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2021_(%).csv a ../data/raw/filtering/inactivity_rate_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2021_(%).csv
# Movido: ../data/raw/mean_weekly_hours_actually_worked_per_employee_by_sex_and_age.csv a ../data/raw/filtering/mean_weekly_hours_actually_worked_per_employee_by_sex_and_age.csv
# Movido: ../data/raw/youth_unemployment_rate_by_sex,_age_and_school_attendance_status_(%).csv a ../data/raw/filtering/youth_unemployment_rate_by_sex,_age_and_school_attendance_status_(%).csv
# Movido: ../data/raw/population_by_sex_and_age_--_un_estimates_and_projections,_july_2022_(thousands).csv a ../data/raw/filtering/population_by_sex_and_age_--_un_estimates_and_projections,_july_2022_(thousands).csv
# Movido: ../data/raw/employment_by_age_and_economic_activity_-_isic_level_2_(thousands).csv a ../data/raw/filtering/employment_by_age_and_economic_activity_-_isic_level_2_(thousands).csv
# Movido: ../data/raw/informal_employment_by_sex,_age_and_marital_status_(thousands).csv a ../data/raw/filtering/informal_employment_by_sex,_age_and_marital_status_(thousands).csv
# Movido: ../data/raw/employment-to-population_ratio_by_sex,_age_and_education_(%).csv a ../data/raw/filtering/employment-to-population_ratio_by_sex,_age_and_education_(%).csv
# Movido: ../data/raw/persons_outside_the_labour_force_by_sex_and_age_(thousands).csv a ../data/raw/filtering/persons_outside_the_labour_force_by_sex_and_age_(thousands).csv
# Movido: ../data/raw/working-age_population_by_sex,_education_and_marital_status_(thousands).csv a ../data/raw/filtering/working-age_population_by_sex,_education_and_marital_status_(thousands).csv
# Movido: ../data/raw/average_monthly_earnings_of_employees_by_sex_and_economic_activity.csv a ../data/raw/filtering/average_monthly_earnings_of_employees_by_sex_and_economic_activity.csv
# Movido: ../data/raw/unemployment_rate_by_sex_and_age_(%).csv a ../data/raw/filtering/unemployment_rate_by_sex_and_age_(%).csv
# Movido: ../data/raw/employment_by_sex,_age_and_economic_class_--_ilo_modelled_estimates,_nov._2023_(thousands).csv a ../data/raw/filtering/employment_by_sex,_age_and_economic_class_--_ilo_modelled_estimates,_nov._2023_(thousands).csv
# Movido: ../data/raw/employees_by_sex,_age_and_economic_activity_(thousands).csv a ../data/raw/filtering/employees_by_sex,_age_and_economic_activity_(thousands).csv
# Movido: ../data/raw/working-age_population_by_sex_and_education_(thousands).csv a ../data/raw/filtering/working-age_population_by_sex_and_education_(thousands).csv
# Movido: ../data/raw/sdg_indicator_8.5.1_-_average_hourly_earnings_of_employees_by_sex_(local_currency).csv a ../data/raw/filtering/sdg_indicator_8.5.1_-_average_hourly_earnings_of_employees_by_sex_(local_currency).csv
# Movido: ../data/raw/unemployment_rate_by_sex_and_age_--_ilo_modelled_estimates,_may_2024_(%).csv a ../data/raw/filtering/unemployment_rate_by_sex_and_age_--_ilo_modelled_estimates,_may_2024_(%).csv
# Movido: ../data/raw/employment_outside_the_formal_sector_by_sex,_age_and_economic_activity_(thousands).csv a ../data/raw/filtering/employment_outside_the_formal_sector_by_sex,_age_and_economic_activity_(thousands).csv
# Movido: ../data/raw/persons_outside_the_labour_force_by_sex_and_age_--_ilo_modelled_estimates,_nov._2023_(thousands).csv a ../data/raw/filtering/persons_outside_the_labour_force_by_sex_and_age_--_ilo_modelled_estimates,_nov._2023_(thousands).csv
# Movido: ../data/raw/youth_inactivity_rate_by_sex,_age_and_education_(%).csv a ../data/raw/filtering/youth_inactivity_rate_by_sex,_age_and_education_(%).csv
# Movido: ../data/raw/working-age_population_by_sex,_age_and_marital_status_(thousands).csv a ../data/raw/filtering/working-age_population_by_sex,_age_and_marital_status_(thousands).csv
# Movido: ../data/raw/share_of_employment_outside_the_formal_sector_by_sex,_age_and_occupation_(%).csv a ../data/raw/filtering/share_of_employment_outside_the_formal_sector_by_sex,_age_and_occupation_(%).csv
# Movido: ../data/raw/youth_outside_the_labour_force_by_sex,_age_and_education_(thousands).csv a ../data/raw/filtering/youth_outside_the_labour_force_by_sex,_age_and_education_(thousands).csv
# Movido: ../data/raw/inactivity_rate_by_sex,_age_and_education_(%).csv a ../data/raw/filtering/inactivity_rate_by_sex,_age_and_education_(%).csv
# Movido: ../data/raw/employees_by_sex,_age_and_occupation_(thousands).csv a ../data/raw/filtering/employees_by_sex,_age_and_occupation_(thousands).csv
# Movido: ../data/raw/average_hourly_earnings_of_employees_by_sex_and_education.csv a ../data/raw/filtering/average_hourly_earnings_of_employees_by_sex_and_education.csv
# Movido: ../data/raw/combined_rate_of_unemployment_and_potential_labour_force_(lu3)_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2020_(%).csv a ../data/raw/filtering/combined_rate_of_unemployment_and_potential_labour_force_(lu3)_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2020_(%).csv
# Movido: ../data/raw/unemployment_by_sex,_age_and_duration_(thousands).csv a ../data/raw/filtering/unemployment_by_sex,_age_and_duration_(thousands).csv
# Movido: ../data/raw/working-age_population_by_sex,_education_and_labour_market_status_(thousands).csv a ../data/raw/filtering/working-age_population_by_sex,_education_and_labour_market_status_(thousands).csv
# Movido: ../data/raw/mean_weekly_hours_actually_worked_per_employed_person_by_sex,_age_and_public-private_sector.csv a ../data/raw/filtering/mean_weekly_hours_actually_worked_per_employed_person_by_sex,_age_and_public-private_sector.csv
# Movido: ../data/raw/employment-to-population_ratio_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2021_(%).csv a ../data/raw/filtering/employment-to-population_ratio_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2021_(%).csv
# Movido: ../data/raw/employees_by_sex_and_age_(thousands).csv a ../data/raw/filtering/employees_by_sex_and_age_(thousands).csv
# Movido: ../data/raw/unemployment_by_sex,_age_and_education_(thousands).csv a ../data/raw/filtering/unemployment_by_sex,_age_and_education_(thousands).csv
# Movido: ../data/raw/prime-age_employment-to-population_ratio_by_sex,_household_type_and_presence_of_children_(%).csv a ../data/raw/filtering/prime-age_employment-to-population_ratio_by_sex,_household_type_and_presence_of_children_(%).csv
# Movido: ../data/raw/employees_by_sex,_age_and_public-private_sector_(thousands).csv a ../data/raw/filtering/employees_by_sex,_age_and_public-private_sector_(thousands).csv
# Movido: ../data/raw/labour_force_participation_rate_by_sex_and_age_--_ilo_modelled_estimates,_nov._2023_(%).csv a ../data/raw/filtering/labour_force_participation_rate_by_sex_and_age_--_ilo_modelled_estimates,_nov._2023_(%).csv
# Movido: ../data/raw/employment_by_sex,_age_and_working_time_arrangement_(thousands).csv a ../data/raw/filtering/employment_by_sex,_age_and_working_time_arrangement_(thousands).csv
# Movido: ../data/raw/employment_by_sex,_age_and_occupation_(thousands).csv a ../data/raw/filtering/employment_by_sex,_age_and_occupation_(thousands).csv
# Movido: ../data/raw/informal_employment_rate_by_sex,_age_and_marital_status_(%).csv a ../data/raw/filtering/informal_employment_rate_by_sex,_age_and_marital_status_(%).csv
# Movido: ../data/raw/combined_rate_of_time-related_underemployment_and_unemployment_(lu2)_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2020_(%).csv a ../data/raw/filtering/combined_rate_of_time-related_underemployment_and_unemployment_(lu2)_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2020_(%).csv
# Movido: ../data/raw/potential_labour_force_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2020_(thousands).csv a ../data/raw/filtering/potential_labour_force_by_sex,_age_and_rural_-_urban_areas_--_ilo_modelled_estimates,_nov._2020_(thousands).csv
# Movido: ../data/raw/unemployment_by_sex,_age_and_marital_status_(thousands).csv a ../data/raw/filtering/unemployment_by_sex,_age_and_marital_status_(thousands).csv
# Movido: ../data/raw/unemployment_by_sex_and_age_--_ilo_modelled_estimates,_may_2024_(thousands).csv a ../data/raw/filtering/unemployment_by_sex_and_age_--_ilo_modelled_estimates,_may_2024_(thousands).csv
# Movido: ../data/raw/persons_outside_the_labour_force_by_sex,_age_and_education_(thousands).csv a ../data/raw/filtering/persons_outside_the_labour_force_by_sex,_age_and_education_(thousands).csv
# Movido: ../data/raw/persons_outside_the_labour_force_by_sex,_age_and_marital_status_(thousands).csv a ../data/raw/filtering/persons_outside_the_labour_force_by_sex,_age_and_marital_status_(thousands).csv
# Movido: ../data/raw/youth_working-age_population_by_sex,_age_and_labour_market_status_(thousands).csv a ../data/raw/filtering/youth_working-age_population_by_sex,_age_and_labour_market_status_(thousands).csv
# Movido: ../data/raw/working-age_population_by_sex_and_marital_status_(thousands).csv a ../data/raw/filtering/working-age_population_by_sex_and_marital_status_(thousands).csv
# Movido: ../data/raw/labour_force_by_sex_and_age_(thousands).csv a ../data/raw/filtering/labour_force_by_sex_and_age_(thousands).csv
